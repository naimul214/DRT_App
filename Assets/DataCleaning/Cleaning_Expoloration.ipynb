# %%
#Importing required libraries:
import pandas as pd
import os

# %%
# Define the relative path to the target directory
output_dir = "../Data"

# Ensure the target directory exists
os.makedirs(output_dir, exist_ok=True)

# %%
# Read the routes.txt file
file_path = "/workspaces/DRT_App/Assets/DataCleaning/routes.txt" 
routes_df = pd.read_csv(file_path)

# Explicitly create a new DataFrame with only the required columns
cleaned_routes = routes_df[["route_id", "route_short_name", "route_long_name"]].copy()

# Create a new column for the concatenated values
cleaned_routes["route_concat"] = cleaned_routes["route_short_name"].astype(str) + ". " + cleaned_routes["route_long_name"]

# Define a custom sorting key function
def custom_sort_key(route_short_name):
    import re
    match = re.match(r'(\d+)([A-Za-z]*)', route_short_name)
    if match:
        num_part = int(match.group(1))
        alpha_part = match.group(2)
        return (num_part, alpha_part or "")
    return (float('inf'), route_short_name)

# Apply the custom sorting
cleaned_routes["sort_key"] = cleaned_routes["route_short_name"].apply(custom_sort_key)
cleaned_routes = cleaned_routes.sort_values(by="sort_key").drop(columns=["sort_key"])
# Reset the index
cleaned_routes = cleaned_routes.reset_index(drop=True)
cleaned_routes.head(20)
# Out:
#    route_id route_short_name route_long_name    route_concat
# 0       101              101       Route 101  101. Route 101
# 1       112              112       Route 112  112. Route 112
# 2       118              118       Route 118  118. Route 118
# 3       121              121       Route 121  121. Route 121
# 4       211              211       Route 211  211. Route 211
# 5       216              216       Route 216  216. Route 216
# 6       224              224       Route 224  224. Route 224
# 7       227              227       Route 227  227. Route 227
# 8       301              301       Route 301  301. Route 301
# 9       302              302       Route 302  302. Route 302
# 10      306              306       Route 306  306. Route 306
# 11      319              319       Route 319  319. Route 319
# 12      392              392       Route 392  392. Route 392
# 13      403              403       Route 403  403. Route 403
# 14      405              405       Route 405  405. Route 405
# 15      407              407       Route 407  407. Route 407
# 16      409              409       Route 409  409. Route 409
# 17      410              410       Route 410  410. Route 410
# 18      411              411       Route 411  411. Route 411
# 19      419              419       Route 419  419. Route 419

# %%
# Explicitly create a new DataFrame with only the required columns
cleaned_routes = cleaned_routes[["route_id", "route_short_name", "route_concat"]].copy()

cleaned_routes.rename(columns={"route_short_name": "incoming_bus","route_concat": "route_name"}, inplace=True)

cleaned_routes
# Out:
#    route_id incoming_bus      route_name
# 0       101          101  101. Route 101
# 1       112          112  112. Route 112
# 2       118          118  118. Route 118
# 3       121          121  121. Route 121
# 4       211          211  211. Route 211
# 5       216          216  216. Route 216
# 6       224          224  224. Route 224
# 7       227          227  227. Route 227
# 8       301          301  301. Route 301
# 9       302          302  302. Route 302
# 10      306          306  306. Route 306
# 11      319          319  319. Route 319
# 12      392          392  392. Route 392
# 13      403          403  403. Route 403
# 14      405          405  405. Route 405
# 15      407          407  407. Route 407
# 16      409          409  409. Route 409
# 17      410          410  410. Route 410
# 18      411          411  411. Route 411
# 19      419          419  419. Route 419
# 20      421          421  421. Route 421
# 21      423          423  423. Route 423
# 22      502          502  502. Route 502
# 23      507          507  507. Route 507
# 24      605          605  605. Route 605
# 25      900          900  900. PULSE 900
# 26      901          901  901. PULSE 901
# 27      902          902  902. Route 902
# 28      905          905  905. Route 905
# 29      915          915  915. PULSE 915
# 30      916          916  916. PULSE 916
# 31      917          917  917. Route 917
# 32      920          920  920. Route 920
# 33      921          921  921. Route 921
# 34       N1           N1    N1. Route N1
# 35       N2           N2    N2. Route N2

# %%
# Construct the full path for the output file
output_file_path = os.path.join(output_dir, "Routes.txt")

# Optionally save the updated data to a new file
cleaned_routes.to_csv(output_file_path, index=False)

# %%
# Read the trips.txt file
file_path_1 = "/workspaces/DRT_App/Assets/DataCleaning/trips.txt"  # Replace with the actual path if needed
trips_df = pd.read_csv(file_path_1)
trips_df.head(30)
# Out:
#    route_id service_id                           trip_id  \
# 0       403    Weekday   100__401011_Timetable_-_2025-02
# 1       403    Weekday   101__401036_Timetable_-_2025-02
# 2       403    Weekday  1025__401068_Timetable_-_2025-02
# 3       403    Weekday  1026__401068_Timetable_-_2025-02
# 4       403    Weekday  1027__401068_Timetable_-_2025-02
# 5       403    Weekday  1028__401030_Timetable_-_2025-02
# 6       403    Weekday  1029__401030_Timetable_-_2025-02
# 7       403    Weekday   102__401008_Timetable_-_2025-02
# 8       403    Weekday  1030__401030_Timetable_-_2025-02
# 9       403    Weekday  1031__401030_Timetable_-_2025-02
# 10      403    Weekday  1032__401030_Timetable_-_2025-02
# 11      403    Weekday  1033__401030_Timetable_-_2025-02
# 12      403    Weekday  1034__401068_Timetable_-_2025-02
# 13      403    Weekday  1035__401068_Timetable_-_2025-02
# 14      403    Weekday  1036__401068_Timetable_-_2025-02
# 15      403    Weekday  1037__401068_Timetable_-_2025-02
# 16      403    Weekday  1038__401030_Timetable_-_2025-02
# 17      403    Weekday  1039__401030_Timetable_-_2025-02
# 18      403    Weekday   103__401037_Timetable_-_2025-02
# 19      403    Weekday  1040__401030_Timetable_-_2025-02
# 20      403    Weekday  1041__401030_Timetable_-_2025-02
# 21      403    Weekday  1042__401030_Timetable_-_2025-02
# 22      403    Weekday  1043__401030_Timetable_-_2025-02
# 23      423    Weekday  1044__401088_Timetable_-_2025-02
# 24      423    Weekday  1045__401004_Timetable_-_2025-02
# 25      423    Weekday  1046__401003_Timetable_-_2025-02
# 26      423    Weekday  1047__401092_Timetable_-_2025-02
# 27      423    Weekday  1048__401002_Timetable_-_2025-02
# 28      423    Weekday  1049__401092_Timetable_-_2025-02
# 29      403    Weekday   104__401017_Timetable_-_2025-02
#
#              trip_headsign  direction_id                    block_id  \
# 0   Oshawa Centre Terminal             0  401011_Timetable_-_2025-02
# 1   Oshawa Centre Terminal             0  401036_Timetable_-_2025-02
# 2       B - Phillip Murray             1  401068_Timetable_-_2025-02
# 3       B - Phillip Murray             1  401068_Timetable_-_2025-02
# 4       B - Phillip Murray             1  401068_Timetable_-_2025-02
# 5       B - Phillip Murray             1  401030_Timetable_-_2025-02
# 6       B - Phillip Murray             1  401030_Timetable_-_2025-02
# 7   Oshawa Centre Terminal             0  401008_Timetable_-_2025-02
# 8       B - Phillip Murray             1  401030_Timetable_-_2025-02
# 9       B - Phillip Murray             1  401030_Timetable_-_2025-02
# 10      B - Phillip Murray             1  401030_Timetable_-_2025-02
# 11      B - Phillip Murray             1  401030_Timetable_-_2025-02
# 12  Oshawa Centre Terminal             0  401068_Timetable_-_2025-02
# 13  Oshawa Centre Terminal             0  401068_Timetable_-_2025-02
# 14  Oshawa Centre Terminal             0  401068_Timetable_-_2025-02
# 15  Oshawa Centre Terminal             0  401068_Timetable_-_2025-02
# 16  Oshawa Centre Terminal             0  401030_Timetable_-_2025-02
# 17  Oshawa Centre Terminal             0  401030_Timetable_-_2025-02
# 18  Oshawa Centre Terminal             0  401037_Timetable_-_2025-02
# 19  Oshawa Centre Terminal             0  401030_Timetable_-_2025-02
# 20  Oshawa Centre Terminal             0  401030_Timetable_-_2025-02
# 21  Oshawa Centre Terminal             0  401030_Timetable_-_2025-02
# 22  Oshawa Centre Terminal             0  401030_Timetable_-_2025-02
# 23        Harmony Terminal             0  401088_Timetable_-_2025-02
# 24        Harmony Terminal             0  401004_Timetable_-_2025-02
# 25        Harmony Terminal             0  401003_Timetable_-_2025-02
# 26        Harmony Terminal             0  401092_Timetable_-_2025-02
# 27        Harmony Terminal             0  401002_Timetable_-_2025-02
# 28        Harmony Terminal             0  401092_Timetable_-_2025-02
# 29  Oshawa Centre Terminal             0  401017_Timetable_-_2025-02
#
#                                 shape_id direction_name  wheelchair_accessible
# 0   100.0.1046829277_Timetable_-_2025-02     Northbound                      1
# 1   100.0.1046829277_Timetable_-_2025-02     Northbound                      1
# 2   100.0.1667218438_Timetable_-_2025-02     Southbound                      1
# 3   100.0.1667218438_Timetable_-_2025-02     Southbound                      1
# 4   100.0.1667218438_Timetable_-_2025-02     Southbound                      1
# 5   100.0.1667218438_Timetable_-_2025-02     Southbound                      1
# 6   100.0.1667218438_Timetable_-_2025-02     Southbound                      1
# 7   100.0.1046829277_Timetable_-_2025-02     Northbound                      1
# 8   100.0.1667218438_Timetable_-_2025-02     Southbound                      1
# 9   100.0.1667218438_Timetable_-_2025-02     Southbound                      1
# 10  100.0.1667218438_Timetable_-_2025-02     Southbound                      1
# 11  100.0.1667218438_Timetable_-_2025-02     Southbound                      1
# 12  100.0.1667218439_Timetable_-_2025-02     Northbound                      1
# 13  100.0.1667218439_Timetable_-_2025-02     Northbound                      1
# 14  100.0.1667218439_Timetable_-_2025-02     Northbound                      1
# 15  100.0.1667218439_Timetable_-_2025-02     Northbound                      1
# 16  100.0.1667218439_Timetable_-_2025-02     Northbound                      1
# 17  100.0.1667218439_Timetable_-_2025-02     Northbound                      1
# 18  100.0.1046829277_Timetable_-_2025-02     Northbound                      1
# 19  100.0.1667218439_Timetable_-_2025-02     Northbound                      1
# 20  100.0.1667218439_Timetable_-_2025-02     Northbound                      1
# 21  100.0.1667218439_Timetable_-_2025-02     Northbound                      1
# 22  100.0.1667218439_Timetable_-_2025-02     Northbound                      1
# 23  100.0.1672883331_Timetable_-_2025-02     Northbound                      1
# 24  100.0.1672883331_Timetable_-_2025-02     Northbound                      1
# 25  100.0.1672883331_Timetable_-_2025-02     Northbound                      1
# 26  100.0.1672883331_Timetable_-_2025-02     Northbound                      1
# 27  100.0.1672883331_Timetable_-_2025-02     Northbound                      1
# 28  100.0.1672883331_Timetable_-_2025-02     Northbound                      1
# 29  100.0.1046829277_Timetable_-_2025-02     Northbound                      1

# %%
# Keep only the first occurrence of each distinct combination of route_id, trip_headsign, and direction_id
SelectDirection_df = trips_df[['route_id', 'trip_id', 'trip_headsign', 'direction_id']] \
    .drop_duplicates(subset=['route_id', 'trip_headsign', 'direction_id'], keep='first') \
    .sort_values(by='route_id')

SelectDirection_df
SelectDirection_df1 = SelectDirection_df.copy()

# %%
SelectDirection_df1=SelectDirection_df.copy()
SelectDirection_df
# Out:
#      route_id                           trip_id               trip_headsign  \
# 1505      101  3001__201037_Timetable_-_2025-02              A - Bay Ridges
# 1499      101  2997__201072_Timetable_-_2025-02                  Bay Ridges
# 1580      112    32__201033_Timetable_-_2025-02                 C - Taunton
# 224       112  1391__201004_Timetable_-_2025-02  Pickering Parkway Terminal
# 2661      118  4767__201085_Timetable_-_2025-02  Pickering Parkway Terminal
# ...       ...                               ...                         ...
# 3347      921  5387__401045_Timetable_-_2025-02            Harmony Terminal
# 144        N1  1160__291002_Timetable_-_2025-02                 Scarborough
# 142        N1  1159__491004_Timetable_-_2025-02                      Conlin
# 184        N2  1268__491003_Timetable_-_2025-02                       Bloor
# 182        N2  1266__491001_Timetable_-_2025-02             Windfields Farm
#
#       direction_id
# 1505             0
# 1499             1
# 1580             0
# 224              1
# 2661             1
# ...            ...
# 3347             0
# 144              1
# 142              0
# 184              1
# 182              0
#
# [102 rows x 4 columns]

# %%
display = SelectDirection_df[(SelectDirection_df["route_id"] == "4486_88181")]
display
# Out:
# Empty DataFrame
# Columns: [route_id, trip_id, trip_headsign, direction_id]
# Index: []

# %%
# Construct the full path for the output file
output_file_path1 = os.path.join(output_dir, "Towards.txt")

# Save the updated data to a new file
SelectDirection_df.to_csv(output_file_path1, index=False)  #Print this file into assets/data

# %%
# Read the Routes.txt file
file_path_2 = "/workspaces/DRT_App/Assets/Data/Routes.txt"  
routes_df = pd.read_csv(file_path_2)

routes_df.head(100)
# Out:
#    route_id incoming_bus      route_name
# 0       101          101  101. Route 101
# 1       112          112  112. Route 112
# 2       118          118  118. Route 118
# 3       121          121  121. Route 121
# 4       211          211  211. Route 211
# 5       216          216  216. Route 216
# 6       224          224  224. Route 224
# 7       227          227  227. Route 227
# 8       301          301  301. Route 301
# 9       302          302  302. Route 302
# 10      306          306  306. Route 306
# 11      319          319  319. Route 319
# 12      392          392  392. Route 392
# 13      403          403  403. Route 403
# 14      405          405  405. Route 405
# 15      407          407  407. Route 407
# 16      409          409  409. Route 409
# 17      410          410  410. Route 410
# 18      411          411  411. Route 411
# 19      419          419  419. Route 419
# 20      421          421  421. Route 421
# 21      423          423  423. Route 423
# 22      502          502  502. Route 502
# 23      507          507  507. Route 507
# 24      605          605  605. Route 605
# 25      900          900  900. PULSE 900
# 26      901          901  901. PULSE 901
# 27      902          902  902. Route 902
# 28      905          905  905. Route 905
# 29      915          915  915. PULSE 915
# 30      916          916  916. PULSE 916
# 31      917          917  917. Route 917
# 32      920          920  920. Route 920
# 33      921          921  921. Route 921
# 34       N1           N1    N1. Route N1
# 35       N2           N2    N2. Route N2

# %%
# Merge route_name into trips_df based on route_id
trips_df = trips_df.merge(routes_df[["route_id", "route_name","incoming_bus"]], on='route_id', how='left')
# Organising trips_df
trips_df = trips_df[["trip_id","route_id","incoming_bus","route_name","trip_headsign","direction_id"]].copy()

trips_df.head(30)
# Out:
#                              trip_id route_id incoming_bus      route_name  \
# 0    100__401011_Timetable_-_2025-02      403          403  403. Route 403
# 1    101__401036_Timetable_-_2025-02      403          403  403. Route 403
# 2   1025__401068_Timetable_-_2025-02      403          403  403. Route 403
# 3   1026__401068_Timetable_-_2025-02      403          403  403. Route 403
# 4   1027__401068_Timetable_-_2025-02      403          403  403. Route 403
# 5   1028__401030_Timetable_-_2025-02      403          403  403. Route 403
# 6   1029__401030_Timetable_-_2025-02      403          403  403. Route 403
# 7    102__401008_Timetable_-_2025-02      403          403  403. Route 403
# 8   1030__401030_Timetable_-_2025-02      403          403  403. Route 403
# 9   1031__401030_Timetable_-_2025-02      403          403  403. Route 403
# 10  1032__401030_Timetable_-_2025-02      403          403  403. Route 403
# 11  1033__401030_Timetable_-_2025-02      403          403  403. Route 403
# 12  1034__401068_Timetable_-_2025-02      403          403  403. Route 403
# 13  1035__401068_Timetable_-_2025-02      403          403  403. Route 403
# 14  1036__401068_Timetable_-_2025-02      403          403  403. Route 403
# 15  1037__401068_Timetable_-_2025-02      403          403  403. Route 403
# 16  1038__401030_Timetable_-_2025-02      403          403  403. Route 403
# 17  1039__401030_Timetable_-_2025-02      403          403  403. Route 403
# 18   103__401037_Timetable_-_2025-02      403          403  403. Route 403
# 19  1040__401030_Timetable_-_2025-02      403          403  403. Route 403
# 20  1041__401030_Timetable_-_2025-02      403          403  403. Route 403
# 21  1042__401030_Timetable_-_2025-02      403          403  403. Route 403
# 22  1043__401030_Timetable_-_2025-02      403          403  403. Route 403
# 23  1044__401088_Timetable_-_2025-02      423          423  423. Route 423
# 24  1045__401004_Timetable_-_2025-02      423          423  423. Route 423
# 25  1046__401003_Timetable_-_2025-02      423          423  423. Route 423
# 26  1047__401092_Timetable_-_2025-02      423          423  423. Route 423
# 27  1048__401002_Timetable_-_2025-02      423          423  423. Route 423
# 28  1049__401092_Timetable_-_2025-02      423          423  423. Route 423
# 29   104__401017_Timetable_-_2025-02      403          403  403. Route 403
#
#              trip_headsign  direction_id
# 0   Oshawa Centre Terminal             0
# 1   Oshawa Centre Terminal             0
# 2       B - Phillip Murray             1
# 3       B - Phillip Murray             1
# 4       B - Phillip Murray             1
# 5       B - Phillip Murray             1
# 6       B - Phillip Murray             1
# 7   Oshawa Centre Terminal             0
# 8       B - Phillip Murray             1
# 9       B - Phillip Murray             1
# 10      B - Phillip Murray             1
# 11      B - Phillip Murray             1
# 12  Oshawa Centre Terminal             0
# 13  Oshawa Centre Terminal             0
# 14  Oshawa Centre Terminal             0
# 15  Oshawa Centre Terminal             0
# 16  Oshawa Centre Terminal             0
# 17  Oshawa Centre Terminal             0
# 18  Oshawa Centre Terminal             0
# 19  Oshawa Centre Terminal             0
# 20  Oshawa Centre Terminal             0
# 21  Oshawa Centre Terminal             0
# 22  Oshawa Centre Terminal             0
# 23        Harmony Terminal             0
# 24        Harmony Terminal             0
# 25        Harmony Terminal             0
# 26        Harmony Terminal             0
# 27        Harmony Terminal             0
# 28        Harmony Terminal             0
# 29  Oshawa Centre Terminal             0

# %%
# Read the stop_times.txt file
file_path_3 = "/workspaces/DRT_App/Assets/DataCleaning/stop_times.txt"  
stop_times_df = pd.read_csv(file_path_3)
stop_times_df1 = stop_times_df.copy()
stop_times_df.head(100)
# Out:
#                              trip_id arrival_time departure_time  stop_id  \
# 0   4984__401007_Timetable_-_2025-02     16:29:00       16:29:00     2585
# 1   4984__401007_Timetable_-_2025-02     16:31:13       16:31:13     1053
# 2   4984__401007_Timetable_-_2025-02     16:33:23       16:33:23      941
# 3   4984__401007_Timetable_-_2025-02     16:34:40       16:34:40      942
# 4   4984__401007_Timetable_-_2025-02     16:34:59       16:34:59     1286
# ..                               ...          ...            ...      ...
# 95  1760__261026_Timetable_-_2025-02     13:55:33       13:55:33      209
# 96  1760__261026_Timetable_-_2025-02     13:56:08       13:56:08      210
# 97  1760__261026_Timetable_-_2025-02     13:56:48       13:56:48      211
# 98  1760__261026_Timetable_-_2025-02     13:57:42       13:57:42      212
# 99  1760__261026_Timetable_-_2025-02     13:58:01       13:58:01      213
#
#     stop_sequence stop_headsign  pickup_type  drop_off_type  \
# 0               1           NaN            0              0
# 1               2           NaN            0              0
# 2               3           NaN            0              0
# 3               4           NaN            0              0
# 4               5           NaN            0              0
# ..            ...           ...          ...            ...
# 95             42           NaN            0              0
# 96             43           NaN            0              0
# 97             44           NaN            0              0
# 98             45           NaN            0              0
# 99             46           NaN            0              0
#
#     shape_dist_traveled  timepoint
# 0                   NaN          1
# 1                   NaN          0
# 2                   NaN          0
# 3                   NaN          0
# 4                   NaN          0
# ..                  ...        ...
# 95                  NaN          0
# 96                  NaN          1
# 97                  NaN          0
# 98                  NaN          0
# 99                  NaN          0
#
# [100 rows x 10 columns]

# %%
StopTimesPerTrip_df = stop_times_df[["trip_id","stop_id","arrival_time"]].copy()
StopTimesPerTrip_df
# Out:
#                                  trip_id  stop_id arrival_time
# 0       4984__401007_Timetable_-_2025-02     2585     16:29:00
# 1       4984__401007_Timetable_-_2025-02     1053     16:31:13
# 2       4984__401007_Timetable_-_2025-02      941     16:33:23
# 3       4984__401007_Timetable_-_2025-02      942     16:34:40
# 4       4984__401007_Timetable_-_2025-02     1286     16:34:59
# ...                                  ...      ...          ...
# 155605  1628__201032_Timetable_-_2025-02      326     17:01:43
# 155606  1628__201032_Timetable_-_2025-02      327     17:02:30
# 155607  1628__201032_Timetable_-_2025-02      328     17:03:00
# 155608  1628__201032_Timetable_-_2025-02      329     17:03:27
# 155609  1628__201032_Timetable_-_2025-02     2576     17:05:00
#
# [155610 rows x 3 columns]

# %%
StopTimesPerTrip_df.dtypes
# Out:
# trip_id         object
# stop_id          int64
# arrival_time    object
# dtype: object

# %%
# Construct the full path for the output file
output_file_path3 = os.path.join(output_dir, "StopTimesPerTrip.txt")

# Saving stop_times_per_route_df into StopTimesPerRoute.txt
StopTimesPerTrip_df.to_csv(output_file_path3, index=False) #Print this file into assets/data

# %%
SelectDirection_df1
# Out:
#      route_id                           trip_id               trip_headsign  \
# 1505      101  3001__201037_Timetable_-_2025-02              A - Bay Ridges
# 1499      101  2997__201072_Timetable_-_2025-02                  Bay Ridges
# 1580      112    32__201033_Timetable_-_2025-02                 C - Taunton
# 224       112  1391__201004_Timetable_-_2025-02  Pickering Parkway Terminal
# 2661      118  4767__201085_Timetable_-_2025-02  Pickering Parkway Terminal
# ...       ...                               ...                         ...
# 3347      921  5387__401045_Timetable_-_2025-02            Harmony Terminal
# 144        N1  1160__291002_Timetable_-_2025-02                 Scarborough
# 142        N1  1159__491004_Timetable_-_2025-02                      Conlin
# 184        N2  1268__491003_Timetable_-_2025-02                       Bloor
# 182        N2  1266__491001_Timetable_-_2025-02             Windfields Farm
#
#       direction_id
# 1505             0
# 1499             1
# 1580             0
# 224              1
# 2661             1
# ...            ...
# 3347             0
# 144              1
# 142              0
# 184              1
# 182              0
#
# [102 rows x 4 columns]

# %%
SelectDirection_df1["rout_dir_id_concat"] = (SelectDirection_df1["route_id"] + SelectDirection_df1["direction_id"].astype(str))
# Explicitly create a new DataFrame with only the required columns
SelectDirection_df1 = SelectDirection_df1[["trip_id", "route_id","direction_id", "rout_dir_id_concat"]].copy()

# %%
SelectDirection_df1
# Out:
#                                trip_id route_id  direction_id  \
# 1505  3001__201037_Timetable_-_2025-02      101             0
# 1499  2997__201072_Timetable_-_2025-02      101             1
# 1580    32__201033_Timetable_-_2025-02      112             0
# 224   1391__201004_Timetable_-_2025-02      112             1
# 2661  4767__201085_Timetable_-_2025-02      118             1
# ...                                ...      ...           ...
# 3347  5387__401045_Timetable_-_2025-02      921             0
# 144   1160__291002_Timetable_-_2025-02       N1             1
# 142   1159__491004_Timetable_-_2025-02       N1             0
# 184   1268__491003_Timetable_-_2025-02       N2             1
# 182   1266__491001_Timetable_-_2025-02       N2             0
#
#      rout_dir_id_concat
# 1505               1010
# 1499               1011
# 1580               1120
# 224                1121
# 2661               1181
# ...                 ...
# 3347               9210
# 144                 N11
# 142                 N10
# 184                 N21
# 182                 N20
#
# [102 rows x 4 columns]

# %%
SelectDirection_df1.dtypes
# Out:
# trip_id               object
# route_id              object
# direction_id           int64
# rout_dir_id_concat    object
# dtype: object

# %%
stop_times_df1
# Out:
#                                  trip_id arrival_time departure_time  stop_id  \
# 0       4984__401007_Timetable_-_2025-02     16:29:00       16:29:00     2585
# 1       4984__401007_Timetable_-_2025-02     16:31:13       16:31:13     1053
# 2       4984__401007_Timetable_-_2025-02     16:33:23       16:33:23      941
# 3       4984__401007_Timetable_-_2025-02     16:34:40       16:34:40      942
# 4       4984__401007_Timetable_-_2025-02     16:34:59       16:34:59     1286
# ...                                  ...          ...            ...      ...
# 155605  1628__201032_Timetable_-_2025-02     17:01:43       17:01:43      326
# 155606  1628__201032_Timetable_-_2025-02     17:02:30       17:02:30      327
# 155607  1628__201032_Timetable_-_2025-02     17:03:00       17:03:00      328
# 155608  1628__201032_Timetable_-_2025-02     17:03:27       17:03:27      329
# 155609  1628__201032_Timetable_-_2025-02     17:05:00       17:05:00     2576
#
#         stop_sequence stop_headsign  pickup_type  drop_off_type  \
# 0                   1           NaN            0              0
# 1                   2           NaN            0              0
# 2                   3           NaN            0              0
# 3                   4           NaN            0              0
# 4                   5           NaN            0              0
# ...               ...           ...          ...            ...
# 155605             28           NaN            0              0
# 155606             29           NaN            0              0
# 155607             30           NaN            0              0
# 155608             31           NaN            0              0
# 155609             32           NaN            0              0
#
#         shape_dist_traveled  timepoint
# 0                       NaN          1
# 1                       NaN          0
# 2                       NaN          0
# 3                       NaN          0
# 4                       NaN          0
# ...                     ...        ...
# 155605                  NaN          0
# 155606                  NaN          0
# 155607                  NaN          0
# 155608                  NaN          0
# 155609                  NaN          1
#
# [155610 rows x 10 columns]

# %%
# Read the stop_times.txt file
file_path_4 = "/workspaces/DRT_App/Assets/DataCleaning/stops.txt"  
stops_df = pd.read_csv(file_path_4)
stops_df["stop_full"] = (stops_df["stop_code"].astype(str) +' - '+stops_df["stop_name"])
stops_df.head(100)
# Out:
#     stop_id  stop_code                                 stop_name  stop_desc  \
# 0        10         10  Garden Northbound @ Bassett (South stop)        NaN
# 1       100        100                McQuay Northbound @ Dundas        NaN
# 2      1000       1000                  Glen Northbound @ Medina        NaN
# 3      1001       1001                     Northbound @ 825 Glen        NaN
# 4      1002       1002                 Malaga Westbound @ Oxford        NaN
# ..      ...        ...                                       ...        ...
# 95     1169       1169                     Bond Westbound @ Park        NaN
# 96      117        117    Country Lane Northbound @ Twin Streams        NaN
# 97     1171       1171                  Bond Westbound @ Gibbons        NaN
# 98     1172       1172                Bond Westbound @ Stevenson        NaN
# 99     1173       1173                  King Westbound @ Waverly        NaN
#
#      stop_lat   stop_lon  zone_id  stop_url  location_type  parent_station  \
# 0   43.903333 -78.941559      NaN       NaN              0             NaN
# 1   43.875932 -78.961715      NaN       NaN              0             NaN
# 2   43.872683 -78.855412      NaN       NaN              0             NaN
# 3   43.875296 -78.856489      NaN       NaN              0             NaN
# 4   43.875507 -78.858799      NaN       NaN              0             NaN
# ..        ...        ...      ...       ...            ...             ...
# 95  43.896215 -78.874631      NaN       NaN              0             NaN
# 96  43.903106 -78.971600      NaN       NaN              0             NaN
# 97  43.895268 -78.878156      NaN       NaN              0             NaN
# 98  43.893883 -78.884232      NaN       NaN              0             NaN
# 99  43.892156 -78.888154      NaN       NaN              0             NaN
#
#     stop_timezone  wheelchair_boarding  preferred  \
# 0             NaN                    1          2
# 1             NaN                    1          2
# 2             NaN                    1          2
# 3             NaN                    1          2
# 4             NaN                    1          2
# ..            ...                  ...        ...
# 95            NaN                    1          1
# 96            NaN                    1          2
# 97            NaN                    1          2
# 98            NaN                    1          1
# 99            NaN                    1          2
#
#                                         stop_full
# 0   10 - Garden Northbound @ Bassett (South stop)
# 1                100 - McQuay Northbound @ Dundas
# 2                 1000 - Glen Northbound @ Medina
# 3                    1001 - Northbound @ 825 Glen
# 4                1002 - Malaga Westbound @ Oxford
# ..                                            ...
# 95                   1169 - Bond Westbound @ Park
# 96   117 - Country Lane Northbound @ Twin Streams
# 97                1171 - Bond Westbound @ Gibbons
# 98              1172 - Bond Westbound @ Stevenson
# 99                1173 - King Westbound @ Waverly
#
# [100 rows x 14 columns]

# %%
# Filter stop_times_df2 by trip_id in SelectDirection_df1
filtered_stop_times_df = stop_times_df1[stop_times_df1['trip_id'].isin(SelectDirection_df1['trip_id'])]

# Display the filtered DataFrame
filtered_stop_times_df
# Out:
#                                  trip_id arrival_time departure_time  stop_id  \
# 1802    4432__461002_Timetable_-_2025-02     18:53:00       18:53:00     2595
# 1803    4432__461002_Timetable_-_2025-02     18:53:58       18:53:58     1287
# 1804    4432__461002_Timetable_-_2025-02     18:54:23       18:54:23     1288
# 1805    4432__461002_Timetable_-_2025-02     18:54:47       18:54:47     1289
# 1806    4432__461002_Timetable_-_2025-02     18:55:37       18:55:37     3228
# ...                                  ...          ...            ...      ...
# 153515  4222__201026_Timetable_-_2025-02     07:48:49       07:48:49     2430
# 153516  4222__201026_Timetable_-_2025-02     07:50:34       07:50:34    94270
# 153517  4222__201026_Timetable_-_2025-02     07:52:29       07:52:29     2443
# 153518  4222__201026_Timetable_-_2025-02     07:53:00       07:53:00     2422
# 153519  4222__201026_Timetable_-_2025-02     07:54:00       07:54:00    93704
#
#         stop_sequence stop_headsign  pickup_type  drop_off_type  \
# 1802                1           NaN            0              0
# 1803                2           NaN            0              0
# 1804                3           NaN            0              0
# 1805                4           NaN            0              0
# 1806                5           NaN            0              0
# ...               ...           ...          ...            ...
# 153515             23           NaN            0              0
# 153516             24           NaN            0              0
# 153517             25           NaN            0              0
# 153518             26           NaN            0              0
# 153519             27           NaN            0              0
#
#         shape_dist_traveled  timepoint
# 1802                    NaN          1
# 1803                    NaN          0
# 1804                    NaN          0
# 1805                    NaN          0
# 1806                    NaN          0
# ...                     ...        ...
# 153515                  NaN          0
# 153516                  NaN          0
# 153517                  NaN          0
# 153518                  NaN          0
# 153519                  NaN          1
#
# [3687 rows x 10 columns]

# %%
StopByTrip_df=filtered_stop_times_df.copy()

# %%
# Explicitly create a new DataFrame with only the required columns
StopByTrip_df = StopByTrip_df[["trip_id", "stop_id","stop_sequence","stop_headsign","pickup_type","drop_off_type"]].copy()
# Renaming columns
StopByTrip_df.rename(columns={'pickup_type': 'trip_ends','drop_off_type': 'trip_starts'}, inplace=True)
StopByTrip_df
# Out:
#                                  trip_id  stop_id  stop_sequence  \
# 1802    4432__461002_Timetable_-_2025-02     2595              1
# 1803    4432__461002_Timetable_-_2025-02     1287              2
# 1804    4432__461002_Timetable_-_2025-02     1288              3
# 1805    4432__461002_Timetable_-_2025-02     1289              4
# 1806    4432__461002_Timetable_-_2025-02     3228              5
# ...                                  ...      ...            ...
# 153515  4222__201026_Timetable_-_2025-02     2430             23
# 153516  4222__201026_Timetable_-_2025-02    94270             24
# 153517  4222__201026_Timetable_-_2025-02     2443             25
# 153518  4222__201026_Timetable_-_2025-02     2422             26
# 153519  4222__201026_Timetable_-_2025-02    93704             27
#
#        stop_headsign  trip_ends  trip_starts
# 1802             NaN          0            0
# 1803             NaN          0            0
# 1804             NaN          0            0
# 1805             NaN          0            0
# 1806             NaN          0            0
# ...              ...        ...          ...
# 153515           NaN          0            0
# 153516           NaN          0            0
# 153517           NaN          0            0
# 153518           NaN          0            0
# 153519           NaN          0            0
#
# [3687 rows x 6 columns]

# %%
# Merge stop_times_df with the selected columns from stops_df on stop_id
StopByTrip_df = StopByTrip_df.merge(stops_df, on="stop_id", how="left")
StopByTrip_df = StopByTrip_df.merge(SelectDirection_df1, on="trip_id", how="left")
StopByTrip_df
# Out:
#                                trip_id  stop_id  stop_sequence stop_headsign  \
# 0     4432__461002_Timetable_-_2025-02     2595              1           NaN
# 1     4432__461002_Timetable_-_2025-02     1287              2           NaN
# 2     4432__461002_Timetable_-_2025-02     1288              3           NaN
# 3     4432__461002_Timetable_-_2025-02     1289              4           NaN
# 4     4432__461002_Timetable_-_2025-02     3228              5           NaN
# ...                                ...      ...            ...           ...
# 3682  4222__201026_Timetable_-_2025-02     2430             23           NaN
# 3683  4222__201026_Timetable_-_2025-02    94270             24           NaN
# 3684  4222__201026_Timetable_-_2025-02     2443             25           NaN
# 3685  4222__201026_Timetable_-_2025-02     2422             26           NaN
# 3686  4222__201026_Timetable_-_2025-02    93704             27           NaN
#
#       trip_ends  trip_starts  stop_code  \
# 0             0            0       2595
# 1             0            0       1287
# 2             0            0       1288
# 3             0            0       1289
# 4             0            0       3228
# ...         ...          ...        ...
# 3682          0            0       2430
# 3683          0            0      94270
# 3684          0            0       2443
# 3685          0            0       2422
# 3686          0            0      93704
#
#                                               stop_name  stop_desc   stop_lat  \
# 0                                Oshawa Centre Terminal        NaN  43.889169
# 1                                  Eastbound @ 431 Gibb        NaN  43.886764
# 2                             Gibb Eastbound @ Grenfell        NaN  43.887267
# 3                             Gibb Eastbound @ Montrave        NaN  43.887759
# 4                               Gibb Eastbound @ Nassau        NaN  43.888869
# ...                                                 ...        ...        ...
# 3682                            Reach Eastbound @ Testa        NaN  44.104464
# 3683                        Nelkydd Northbound @ Planks        NaN  44.110260
# 3684               Brock Street Westbound @ Main Street        NaN  44.109472
# 3685  Toronto Northbound @ Brock Street (North side ...        NaN  44.109303
# 3686                        Railway Southbound @ Albert        NaN  44.109644
#
#       ...  stop_url  location_type  parent_station  stop_timezone  \
# 0     ...       NaN              0             NaN            NaN
# 1     ...       NaN              0             NaN            NaN
# 2     ...       NaN              0             NaN            NaN
# 3     ...       NaN              0             NaN            NaN
# 4     ...       NaN              0             NaN            NaN
# ...   ...       ...            ...             ...            ...
# 3682  ...       NaN              0             NaN            NaN
# 3683  ...       NaN              0             NaN            NaN
# 3684  ...       NaN              0             NaN            NaN
# 3685  ...       NaN              0             NaN            NaN
# 3686  ...       NaN              0             NaN            NaN
#
#       wheelchair_boarding  preferred  \
# 0                       1          2
# 1                       1          2
# 2                       1          2
# 3                       1          2
# 4                       2          2
# ...                   ...        ...
# 3682                    1          2
# 3683                    2          2
# 3684                    1          2
# 3685                    1          2
# 3686                    2          1
#
#                                               stop_full  route_id  \
# 0                         2595 - Oshawa Centre Terminal       901
# 1                           1287 - Eastbound @ 431 Gibb       901
# 2                      1288 - Gibb Eastbound @ Grenfell       901
# 3                      1289 - Gibb Eastbound @ Montrave       901
# 4                        3228 - Gibb Eastbound @ Nassau       901
# ...                                                 ...       ...
# 3682                     2430 - Reach Eastbound @ Testa       605
# 3683                94270 - Nelkydd Northbound @ Planks       605
# 3684        2443 - Brock Street Westbound @ Main Street       605
# 3685  2422 - Toronto Northbound @ Brock Street (Nort...       605
# 3686                93704 - Railway Southbound @ Albert       605
#
#      direction_id rout_dir_id_concat
# 0               0               9010
# 1               0               9010
# 2               0               9010
# 3               0               9010
# 4               0               9010
# ...           ...                ...
# 3682            0               6050
# 3683            0               6050
# 3684            0               6050
# 3685            0               6050
# 3686            0               6050
#
# [3687 rows x 22 columns]

# %%
StopByTrip_df.rename(columns={'rout_dir_id_concat': 'concat'}, inplace=True)

# %%
StopByTrip_df = StopByTrip_df[["route_id","trip_id","direction_id","concat","stop_id","stop_code", "stop_name","stop_full","stop_headsign","stop_sequence",
                              "stop_lat","stop_lon","trip_starts","trip_ends"]].copy()

# %%
StopByTrip_df
# Out:
#      route_id                           trip_id  direction_id concat  stop_id  \
# 0         901  4432__461002_Timetable_-_2025-02             0   9010     2595
# 1         901  4432__461002_Timetable_-_2025-02             0   9010     1287
# 2         901  4432__461002_Timetable_-_2025-02             0   9010     1288
# 3         901  4432__461002_Timetable_-_2025-02             0   9010     1289
# 4         901  4432__461002_Timetable_-_2025-02             0   9010     3228
# ...       ...                               ...           ...    ...      ...
# 3682      605  4222__201026_Timetable_-_2025-02             0   6050     2430
# 3683      605  4222__201026_Timetable_-_2025-02             0   6050    94270
# 3684      605  4222__201026_Timetable_-_2025-02             0   6050     2443
# 3685      605  4222__201026_Timetable_-_2025-02             0   6050     2422
# 3686      605  4222__201026_Timetable_-_2025-02             0   6050    93704
#
#       stop_code                                          stop_name  \
# 0          2595                             Oshawa Centre Terminal
# 1          1287                               Eastbound @ 431 Gibb
# 2          1288                          Gibb Eastbound @ Grenfell
# 3          1289                          Gibb Eastbound @ Montrave
# 4          3228                            Gibb Eastbound @ Nassau
# ...         ...                                                ...
# 3682       2430                            Reach Eastbound @ Testa
# 3683      94270                        Nelkydd Northbound @ Planks
# 3684       2443               Brock Street Westbound @ Main Street
# 3685       2422  Toronto Northbound @ Brock Street (North side ...
# 3686      93704                        Railway Southbound @ Albert
#
#                                               stop_full stop_headsign  \
# 0                         2595 - Oshawa Centre Terminal           NaN
# 1                           1287 - Eastbound @ 431 Gibb           NaN
# 2                      1288 - Gibb Eastbound @ Grenfell           NaN
# 3                      1289 - Gibb Eastbound @ Montrave           NaN
# 4                        3228 - Gibb Eastbound @ Nassau           NaN
# ...                                                 ...           ...
# 3682                     2430 - Reach Eastbound @ Testa           NaN
# 3683                94270 - Nelkydd Northbound @ Planks           NaN
# 3684        2443 - Brock Street Westbound @ Main Street           NaN
# 3685  2422 - Toronto Northbound @ Brock Street (Nort...           NaN
# 3686                93704 - Railway Southbound @ Albert           NaN
#
#       stop_sequence   stop_lat   stop_lon  trip_starts  trip_ends
# 0                 1  43.889169 -78.877279            0          0
# 1                 2  43.886764 -78.876312            0          0
# 2                 3  43.887267 -78.874165            0          0
# 3                 4  43.887759 -78.872047            0          0
# 4                 5  43.888869 -78.867720            0          0
# ...             ...        ...        ...          ...        ...
# 3682             23  44.104464 -79.109229            0          0
# 3683             24  44.110260 -79.110480            0          0
# 3684             25  44.109472 -79.120325            0          0
# 3685             26  44.109303 -79.122461            0          0
# 3686             27  44.109644 -79.125063            0          0
#
# [3687 rows x 14 columns]

# %%
# Construct the full path for the output file
output_file_path4 = os.path.join(output_dir, "StopMapLocation.txt")

# Saving stop_times_per_route_df into StopTimesPerRoute.txt
StopByTrip_df.to_csv(output_file_path4, index=False) #Print this file into assets/data
